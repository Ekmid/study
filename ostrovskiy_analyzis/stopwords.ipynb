# %%
# %pip install -q nltk
# import nltk
# nltk.download('stopwords')
# from nltk.corpus import stopwords
# from nltk import word_tokenize
# from nltk.stem import PorterStemmer
# %pip install -q spacy scikit-learn
import spacy
import numpy as np
import sklearn
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\Мирославик\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
with open("../ostrovskiy_analyzis/texts/Svoi_lydi_sochtemsya_1.txt", "r") as file:
    text_1 = file.read()

with open("../ostrovskiy_analyzis/texts/Bednost_ne_porok_2.txt", "r") as file:
    text_2 = file.read()

with open("../ostrovskiy_analyzis/texts/Groza_3.txt", "r") as file:
    text_3 = file.read()

with open("../ostrovskiy_analyzis/texts/Snegyrochka_4.txt", "r") as file:
    text_4 = file.read()

with open("../ostrovskiy_analyzis/texts/Bespridannica_5.txt", "r") as file:
    text_5 = file.read()

with open("../ostrovskiy_analyzis/texts/Bez_vini_vinovatie_6.txt", "r") as file:
    text_6 = file.read()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_texts(texts):
    nlp = spacy.load('ru_core_news_sm')
    preprocessed_texts = []
    for text in texts:
        doc = nlp(text)
        preprocessed_text = ' '.join([token.text for token in doc if not token.is_punct and not token.is_stop])
        preprocessed_texts.append(preprocessed_text)
    return preprocessed_texts

def compute_cosine_similarity(texts):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(texts)
    similarity_matrix = cosine_similarity(tfidf_matrix)
    return similarity_matrix

# %%
txt1 = preprocess_texts(text_1)
txt1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Мирославик\Desktop\study\python\study\ostrovskiy_analyzis\stopwords.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%9C%D0%B8%D1%80%D0%BE%D1%81%D0%BB%D0%B0%D0%B2%D0%B8%D0%BA/Desktop/study/python/study/ostrovskiy_analyzis/stopwords.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> txt1 = preprocess_texts(text_1)
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%9C%D0%B8%D1%80%D0%BE%D1%81%D0%BB%D0%B0%D0%B2%D0%B8%D0%BA/Desktop/study/python/study/ostrovskiy_analyzis/stopwords.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> txt1
#
# c:\Users\Мирославик\Desktop\study\python\study\ostrovskiy_analyzis\stopwords.ipynb Cell 4 line 8
# ...

# %%
# words_filtered_1 = [token.text for token in doc_1 if not token.is_punct and not token.is_stop]
# words_filtered_2 = [token.text for token in doc_2 if not token.is_punct and not token.is_stop]
# words_filtered_3 = [token.text for token in doc_3 if not token.is_punct and not token.is_stop]
# words_filtered_4 = [token.text for token in doc_4 if not token.is_punct and not token.is_stop]
# words_filtered_5 = [token.text for token in doc_5 if not token.is_punct and not token.is_stop]
# words_filtered_6 = [token.text for token in doc_6 if not token.is_punct and not token.is_stop]
# words_filtered_1

# %%
# class PreProc:
#     def __init__(self):
#         self.name = name
    
#     def __filtering__(doc):
#         words_filtered = [token.text for token in doc if not token.is_punct and not token.is_stop]
        
#         return words_filtered

# %%
# one = PreProc.__filtering__(doc_1)
# print(one)
# Out:
# ['Спасибо', 'скачали', 'книгу', 'бесплатной', 'электронной', 'библиотеке', 'BooksCafe', 'Net', 'http://bookscafe.net', '\n\n', 'книги', 'автора', 'http://bookscafe.net/author/ostrovskiy_aleksandr-12306.html', '\n\n', 'книга', 'форматах', 'http://bookscafe.net/book/ostrovskiy_aleksandr-svoi_lyudi_sochtemsya-50317.html', '\n\n', 'Приятного', 'чтения', '\n\n\n\n\n', 'Островский', 'Александр', 'Николаевич', '\n\n', 'люди', 'сочтемся', '\n\n\n', 'Александр', 'Николаевич', 'Островский', '\n\n', 'люди', 'сочтемся', '\n\n', 'Большов', 'Самсон', 'Силыч', '\n\n', 'Купец', '\n\n', 'Аграфена', 'Кондратьевна', '\n\n', 'жена', '\n\n', 'Липочка', '\n\n', 'дочь', '\n\n', 'Подхалюзин', '\n\n', 'Приказчик', '\n\n', 'Аграфена', 'Кондратьевна', '\n\n', 'Сваха', '\n\n', 'Фоминишна', '\n\n', 'Ключница', '\n\n', 'Рисположенский', 'Сысой', 'Псоич', '\n\n', 'стряпчий', '\n\n', 'Тишка', '\n\n', 'мальчик', '\n\n', 'ДЕЙСТВИЕ', 'ПЕРВОЕ', '\n\n', 'Гостиная', 'доме', 'Большова', '\n\n', 'ЯВЛЕНИЕ', 'ПЕРВОЕ', '\n\n'
# ...

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfTransformer
# from sklearn.preprocessing import normalize

# def preprocess_texts(texts):
#     count_vectorizer = CountVectorizer()
#     term_counts = count_vectorizer.fit_transform(texts)
    
#     tfidf_transformer = TfidfTransformer()
#     tfidf_matrix = tfidf_transformer.fit_transform(term_counts)
    
#     normalized_tfidf_matrix = normalize(tfidf_matrix, norm='l2', axis=1)
    
#     return normalized_tfidf_matrix

# %%
# from sklearn.metrics.pairwise import cosine_similarity

# def compute_cosine_similarity(text_vector1, text_vector2):
#     similarity = cosine_similarity(text_vector1, text_vector2)
    
#     return similarity

# %%
# txt = preprocess_texts(text_1)
# txt

# %%
# words = word_tokenize(text)
# len(words)

# %%
# stop = stopwords.words('russian')
# words_filter = [word for word in words if word not in stop]
# len(words_filter)

# %%
# procent = (len(words) - len(words_filter)) / len(words) * 100
# procent

# %%
# ps = PorterStemmer()
# stem_filter = [ps.stem(word) for word in words_filter]
# stem_filtered = [word for word in words if word not in stop]
# len(stem_filtered)
